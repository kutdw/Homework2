# %% [markdown]
# #Assignment 3
# - 2010136060 백동우
# - Due Date: 2015년 10월 21일 (수), 23시 59분

# %% [markdown]
# ###문제1)  L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.
#
# 1)
# L[1:3] = [100]
# print L
# 2)
# L[1:3] = [(100)]
# print L
# 3)
# L[1:3] = 100
# print L
# 4)
# L[1:3] = (100)
# print L
# 5)
# L[1:3] = (100, 101, 102)
# print L
# 6)
# L[1:3] = [100, 101, 102]
# print L
# 7)
# L[1:3] = [(100, 101, 102)]
# print L
# 8)
# L[1:3] = [[100, 101, 102]]
# print L

# %%
L=[1, 2, 3, 4, 5]

#1)
L[1:3] = [100]
print '1) = ', L
#2)
L[1:3] = [(100)]
print '2) = ', L
#3)
##L[1:3] = 100
print '3) = ',  "에러"
#4)
##L[1:3] = (100)
print '4) = ', '에러'
#5)
L[1:3] = (100, 101, 102)
print '5) = ', L
#6)
L[1:3] = [100, 101, 102]
print '6) = ', L
#7)
L[1:3] = [(100, 101, 102)]
print '7) = ', L
#8)
L[1:3] = [[100, 101, 102]]
print '8) = ', L
# Out:
# 1) =  [1, 100, 4, 5]
# 2) =  [1, 100, 5]
# 3) =  에러
# 4) =  에러
# 5) =  [1, 100, 101, 102]
# 6) =  [1, 100, 101, 102, 102]
# 7) =  [1, (100, 101, 102), 102, 102]
# 8) =  [1, [100, 101, 102], 102]

# %% [markdown]
# 1번은 서로다른 크기에 대한 슬라이스 치환으로 1번과 2번 인덱스값을 100으로 치환하였다.<br>
# 2번은 슬라이스 치환으로 변경된 값의 1번과 2번 인덱스값을 (100)으로 치환하였다.<br>
# 3번은 치환을 할때 값을 리터럴형으로 감싸줘야되는데 그러지 않아 에러가 났다.<br>
# 4번은 치환을 할때 튜플로 감싸려면 (,)를 찍어주여야 하기 때문에 에러가 났다.<br>
# 5번은 서로다른 크기에 대한 슬라이스 치환으로 1번과 2번 인덱스값에 100, 101을 치환하고, 나머지 102값은 새로 추가하였다.<br>
# 6번은 서로다른 크기에 대한 슬라이스 치환으로 1번과 2번 인덱스값에 100,101,102를 치환하였다.<br>
# 7번은 1번과 2번 인덱스값을 튜플형태의 (100,101,102)로 치환하였다.<br>
# 8번은 1번과 2번 인덱스값을 리스트형태의 [100,101,102]로 치환하였다.

# %% [markdown]
# ###문제2)   문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
# 1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고<br>
# 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
S = 'Hello World and Python'
S2 = S.split();
S2.reverse();
S2 = " ".join(S2);
print S2;
S3 = S2.split();
S3 = "".join(S3);
print S3;
# Out:
# Python and World Hello
# PythonandWorldHello

# %% [markdown]
# 1) 먼저 문자열 S를 split 내장함수를 이용하여 각 단어를 리스트에 넣고, reverse()으로 역순으로 정렬시켰다. 그리고 띄어쓰기와 join메소드를 사용하면 역순으로 정렬된 단어들의 공백과 함께 나오게된다.<br>
# 2) 그리고 마찬가지로 split 내장함수를 이용하여 각 단어를 리스트에 넣고, 공백이 없는 join메소드를 이용하여 단어들을 공백이없이 출력하였다.

# %% [markdown]
# ###문제3) 다음 코드를 보고 물음에 답하시오.
# 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
# a[0]=0<br>
# 2) b와 c 객체의 차이는 무엇인가?

# %%
a = [1, 2, 3]
b = a * 3
c = [a] * 3
print b
print c
a[0] = 0

# 1)문제
print
print b
print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
#
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# 1) b는 그대로 출력되었지만 c는 각 리스트원소의 0번째 인덱스값이 0으로 바뀌었다. <br>
# 2) b객체는 a*3의 리스트를 저장하는것이고, c객체는 [a]*3 의 리스트를 레퍼런스 하고있다.

# %% [markdown]
# ###문제4) 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)<br>
# s = '  first star   :   second star   :    third star  '  <br>
# l = ['first star', 'second star', 'third star']  <br>
# 1) for ~ in 문을 이용한 코드를 작성하시오.  <br>
# 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = ' first star : second star : third star ' 
l = [];
s1 = s.split(':');
for ex in s1:
    l.append(ex.strip());
print l;
print

l2 = [k.strip() for k in s1]
print l2;
# Out:
# ['first star', 'second star', 'third star']
#
# ['first star', 'second star', 'third star']

# %% [markdown]
# 1)문자열 s를 split 내장함수를 이용하여 ":"기준으로 분리하여 리스트를 만들고, for문으로 strip을 이용하여 공백을 제거한 값을 l리스트에 추가하였다.<br>
# 2)리스트 내포방식으로 for문으로 s1의 각 원소에 strip()을 이용하여 공백을 제거한 값을 리스트에 추가하였다.

# %% [markdown]
# ###문제5) 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
# 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)<br>
# addall([1]) <br>
# 1 <br>
# addall([1, 2, 3, 4, 5, 6, 7, 8, 9])<br>
# 45
# <br>
# 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)<br>
# addallodd([1])<br>
# 1<br>
# addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])<br>
# 25<br>
# [참고]: 리스트 내포 방식으로 addall() 및 addallodd()함수를 만들 때엔 리스트 내포에 의해 생성된 리스트 결과에 대해 내장 함수를 사용하는 방식을 고려해보시오 (주의: 리스트 내포 방식의 addall() 및 addallodd() 함수의 몸체는 단 1줄로 작성되어야 한다.)

# %%
def addall(list):
    p = 0;
    for k in list:
        p = p+k;
    return p;           

def addallodd(list):
    q = 0;
    for k in list:
        if (k%2==1):
            q = q+k;        
    return q;
         

print addall([1,2,4,-9,3,6,7,9,11]);
print addallodd([1,2,4,-9,3,6,7,9,11]);
# Out:
# 45
# 25

# %% [markdown]
# 리스트 변수 list를 인자로 받는 함수를 위와 같이 정의하였다.

# %%
L = [k+1 for k in range(9)];
print L
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def addall(list):
    return sum([x for x in list if x > 0],0)

print addall([1,2,4,-9,3,6,7,9,11])

def addodd(list):
    return sum([x for x in list if x > 0 and x % 2 == 1],0)

print addodd([1,2,4,-9,3,6,7,9,11])
# Out:
# 43
# 31

# %% [markdown]
# 리스트 내포방식으로 함수를 위와 같이 정의하였다.

# %% [markdown]
# ###문제6) 다음 코드를 보고 물음에 답하시오.
#
# 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가? <br>
# 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
# {'high': [4, 500, 6], 'low': [1, 2, 3]}

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()
print d
print e
print f
print
d['low'] = [10, 20, 30]
d['high'][1] = 500
print d
print e
print f
# Out:
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
#
# {'high': [4, 500, 6], 'low': [10, 20, 30]}
# {'high': [4, 500, 6], 'low': [10, 20, 30]}
# {'high': [4, 500, 6], 'low': [1, 2, 3]}

# %% [markdown]
# 1) e는 d를 레퍼런스하고있기 때문에 d가 수정되면 수정된값을 불러온다.<br>
# 2) F에서 'high'키의 값은 위에서 d['high'][1] = 500 으로 1번 인덱스가 500값을 레퍼런스하라고 변경되었기 때문에 위와 같이 나왔다. 그리고 'low'키의 값은 위에서 d['low'] = [10, 20, 30] 으로 교체되었지만, F가 d.copy()로 Shallow Copy를 하고있기 때문에 그대로 [1,2,3]이 나왔다

# %% [markdown]
# ###문제7) 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
# [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.<br>
# 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.<br>
# 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.<br>
# 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.<br>
# 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}
L =[]
L = d.items();
def eng(t):
    return t[0]

def num(t):
    return t[1]

L.sort(key=eng)
print L
L.sort(key=eng,reverse=True)
print L
L.sort(key=num)
print L
L.sort(key=num,reverse=True)
print L
# Out:
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]
# [('two', 2), ('three', 3), ('one', 1), ('four', 4), ('five', 5)]
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]
# [('five', 5), ('four', 4), ('three', 3), ('two', 2), ('one', 1)]

# %% [markdown]
# 1) 각각 튜플의 0번 인덱스값과 1번 인덱스값을 반환하는 함수를 만들어 sort()함수에 키값을 주어 사전순서대로 오름차순 정렬하여 출력하였다.<br>
# 2) 마찬가지로 sort()함수에 키값과 reverse값을 주어 내림차순으로 출력하였다.<br>
# 3) 값의 오름차순으로 정렬하기위해 튜플의 1번 인덱스값을 반환하는 key를 넣어주어 오름차순으로 정렬하였다.<br>
# 4) 마찬가지로 key값과 reverse값을 주어 값의 내림차순으로 출력하였다.<br>

# %% [markdown]
# ###문제8) 프로젝트 오일러 문제7
# 소수를 크기 순으로 나열하면 2, 3, 5, 7, 11, 13, ... 과 같이 됩니다.
# 이 때 10,001번째의 소수를 구하세요.

# %%
def isPrimeNumber(num):
    t=2
    
    while t<=num:
        rest=num%t

        if rest==0 and t==num:
            return True
        elif rest==0 and t!=num:
            return False
        else:
            t=t+1

    return False

def getPrimeNumber(offset):
    numberOfPrimeNum=0
    
    targetNum=2
    
    while True:
    
        r=isPrimeNumber(targetNum)
        
        if r:
            numberOfPrimeNum=numberOfPrimeNum+1
            
            if numberOfPrimeNum == offset:
                return targetNum

        targetNum=targetNum+1

    return targetNum

r=getPrimeNumber(10001)
print(r)
# Out:
# 104743

# %% [markdown]
# 순서대로 소수를 탐색하는 함수를 만들고 , 그 함수를 이용하여 10,001번째의 소수를 구하였다.

# %% [markdown]
# ###문제9) 프로젝트 오일러 문제8
# 다음은 연속된 1000자리 숫자입니다 (읽기 좋게 50자리씩 잘라놓음).
#
# 73167176531330624919225119674426574742355349194934
# 96983520312774506326239578318016984801869478851843
# 85861560789112949495459501737958331952853208805511
# 12540698747158523863050715693290963295227443043557
# 66896648950445244523161731856403098711121722383113
# 62229893423380308135336276614282806444486645238749
# 30358907296290491560440772390713810515859307960866
# 70172427121883998797908792274921901699720888093776
# 65727333001053367881220235421809751254540594752243
# 52584907711670556013604839586446706324415722155397
# 53697817977846174064955149290862569321978468622482
# 83972241375657056057490261407972968652414535100474
# 82166370484403199890008895243450658541227588666881
# 16427171479924442928230863465674813919123162824586
# 17866458359124566529476545682848912883142607690042
# 24219022671055626321111109370544217506941658960408
# 07198403850962455444362981230987879927244284909188
# 84580156166097919133875499200524063689912560717606
# 05886116467109405077541002256983155200055935729725
# 71636269561882670428252483600823257530420752963450
#
# 여기서 붉게 표시된 71112의 경우 7, 1, 1, 1, 2 각 숫자를 모두 곱하면 14가 됩니다.
#
# 이런 식으로 맨 처음 (7 × 3 × 1 × 6 × 7 = 882) 부터 맨 끝 (6 × 3 × 4 × 5 × 0 = 0) 까지 5자리 숫자들의 곱을 구할 수 있습니다.
# 이렇게 구할 수 있는 5자리 숫자의 곱 중에서 가장 큰 값은 얼마입니까?

# %%
num=7316717653133062491922511967442657474235534919493496983520312774506326239578318016984801\
8694788518438586156078911294949545950173795833195285320880551112540698747158523863050715693290963295227443043557\
6689664895044524452316173185640309871112172238311362229893423380308135336276614282806444486645238749303589072962\
90491560440772390713810515859307960866701724271218839987979087922749219016997208880937766572733300105336788122023\
5421809751254540594752243525849077116705560136048395864467063244157221553975369781797784617406495514929086256932197\
84686224828397224137565705605749026140797296865241453510047482166370484403199890008895243450658541227588666881164271\
714799244429282308634656748139191231628245861786645835912456652947654568284891288314260769004224219022671055626321111\
10937054421750694165896040807198403850962455444362981230987879927244284909188845801561660979191338754992005240636899125\
607176060588611646710940507754100225698315520005593572972571636269561882670428252483600823257530420752963450
num=str(num)

biggestNum=0

startOffSet=0
endOffSet=5

while endOffSet<=1000:
    tempResult=1
    slicedList=num[startOffSet:endOffSet]
    
    for x in slicedList:
        tempResult=tempResult*int(x)

    if(biggestNum < tempResult):
        biggestNum=tempResult

    startOffSet+=1
    endOffSet+=1


print (biggestNum)
# Out:
# 40824

# %% [markdown]
# 반복문과 조건문을 이용하여 숫자 5개의 곱을 구하면서 큰수를 비교하여 모든 숫자를 탐색하고 가장 큰 biggestNum의 수를 출력하였다.

# %% [markdown]
# ###문제10) 프로젝트 오일러 문제9
# 세 자연수 a, b, c 가 피타고라스 정리 a2 + b2 = c2 를 만족하면 피타고라스 수라고 부릅니다 (여기서 a < b < c ).
# 예를 들면 32 + 42 = 9 + 16 = 25 = 52이므로 3, 4, 5는 피타고라스 수입니다.
#
# a + b + c = 1000 인 피타고라스 수 a, b, c는 한 가지 뿐입니다. 이 때, a × b × c 는 얼마입니까?

# %%
n=1
m=2

import math

while True:
    r=math.pow(m,2) + m*n

    if r==500:
        print(m,n)
        break

    m+=1
    if m==500:
        n+=1
        m=n+1

a=math.pow(m,2) - math.pow(n,2)
b=2*m*n
c=math.pow(m,2) + math.pow(n,2)

print(a, b, c)
print "a*b*c =",(a*b*c)
# Out:
# (20, 5)
# (375.0, 200, 425.0)
# a*b*c = 31875000.0

# %% [markdown]
# a^2+b^2=c^2 에서 각 수는 아래와 같이 표현된다.
# a=m^2-n^2
# b=2*m*n
# c=m^2+n^2 (m>n)
# 이것을 a+b+c=1000에 대입하여 전개하면 m^2+mn=500 이 나오고 이 식으로 m과 n을 구하여 a,b,c를 구한다음 계산을 하였다.

# %% [markdown]
# ###문제11) [Incremental Project] 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.

# %%
import urllib2

source = urllib2.urlopen("http://www.naver.com/").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")

words= source.split()
words = ''.join(source)

words=words.replace('!','')
words=words.replace('"','')
words=words.replace('#','')
words=words.replace('$','')
words=words.replace('%','')
words=words.replace('&','')
words=words.replace("'",'')
words=words.replace('(','')
words=words.replace(')','')
words=words.replace('*','')
words=words.replace('+','')
words=words.replace(',','')
words=words.replace('-','')
words=words.replace('.','')
words=words.replace('/','')
words=words.replace(':','')
words=words.replace(';','')
words=words.replace('<','')
words=words.replace('=','')
words=words.replace('>','')
words=words.replace('?','')
words=words.replace('@','')
words=words.replace('[','')
words=words.replace('\\','')
words=words.replace(']','')
words=words.replace('^','')
words=words.replace('_','')
words=words.replace("`",'')
words=words.replace('{','')
words=words.replace('|','')
words=words.replace('}','')
words=words.replace('~','')
words=words.replace('“','')
words=words.replace('”','')
words=words.replace('‘','')
words=words.replace('’','')
words=words.replace('·','')
words=words.replace('【','')
words=words.replace('】','')



words2 = words.split()

s={}
l=[]
#for word in words2:
#    l.append(word)
#    print word,

print
print '네이버 : 총'+str(len(words2))+ '개'

D={}
L=words.split()
for word in L:
    if word in D:
        D[word]+=1
    else:
        D[word]=1
        
for key in D.keys():
    print "%s : %s" % (key, D[key]),;


print 
source = urllib2.urlopen("http://www.daum.net/").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")

words= source.split()
words = ''.join(source)

words=words.replace('!','')
words=words.replace('"','')
words=words.replace('#','')
words=words.replace('$','')
words=words.replace('%','')
words=words.replace('&','')
words=words.replace("'",'')
words=words.replace('(','')
words=words.replace(')','')
words=words.replace('*','')
words=words.replace('+','')
words=words.replace(',','')
words=words.replace('-','')
words=words.replace('.','')
words=words.replace('/','')
words=words.replace(':','')
words=words.replace(';','')
words=words.replace('<','')
words=words.replace('=','')
words=words.replace('>','')
words=words.replace('?','')
words=words.replace('@','')
words=words.replace('[','')
words=words.replace('\\','')
words=words.replace(']','')
words=words.replace('^','')
words=words.replace('_','')
words=words.replace("`",'')
words=words.replace('{','')
words=words.replace('|','')
words=words.replace('}','')
words=words.replace('~','')
words=words.replace('“','')
words=words.replace('”','')
words=words.replace('‘','')
words=words.replace('’','')
words=words.replace('·','')
words=words.replace('【','')
words=words.replace('】','')

words2 = words.split()

s={}
l=[]
#for word in words2:
#    l.append(word)
#    print word,

print
print

print '다음 : 총'+str(len(words2))+ '개'

D={}
L=words.split()
for word in L:
    if word in D:
        D[word]+=1
    else:
        D[word]=1
        
for key in D.keys():
    print "%s : %s" % (key, D[key]),;

source = urllib2.urlopen("http://www.nytimes.com").read()
#print source # 추후 숙제 답안 제출 때엔 왼쪽 라인은 주석처리할 것
for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")

words= source.split()
words = ''.join(source)

words=words.replace('!','')
words=words.replace('"','')
words=words.replace('#','')
words=words.replace('$','')
words=words.replace('%','')
words=words.replace('&','')
words=words.replace("'",'')
words=words.replace('(','')
words=words.replace(')','')
words=words.replace('*','')
words=words.replace('+','')
words=words.replace(',','')
words=words.replace('-','')
words=words.replace('.','')
words=words.replace('/','')
words=words.replace(':','')
words=words.replace(';','')
words=words.replace('<','')
words=words.replace('=','')
words=words.replace('>','')
words=words.replace('?','')
words=words.replace('@','')
words=words.replace('[','')
words=words.replace('\\','')
words=words.replace(']','')
words=words.replace('^','')
words=words.replace('_','')
words=words.replace("`",'')
words=words.replace('{','')
words=words.replace('|','')
words=words.replace('}','')
words=words.replace('~','')
words=words.replace('“','')
words=words.replace('”','')
words=words.replace('‘','')
words=words.replace('’','')
words=words.replace('·','')
words=words.replace('【','')
words=words.replace('】','')



words2 = words.split()

s={}
l=[]
#for word in words2:
#    l.append(word)
#    print word,

print
print '\n\n\n Nytimes : 총'+str(len(words2))+ '개'

D={}
L=words.split()
for word in L:
    if word in D:
        D[word]+=1
    else:
        D[word]=1
        
for key in D.keys():
    print "%s : %s" % (key, D[key]),;

source = urllib2.urlopen("http://www.nytimes.com/").read()
# Out:
# 네이버 : 총4089개
# ...

# %% [markdown]
# replace()로 각 구두문자를 대체하고 split()으로 분리한다음 리스트를 사전에 넣으면서 word의 값을 증가시켰다.
# 그리고 for문을 이용하여 각 키와 키의 개수를출력하였다.

# %% [markdown]
# ##고찰

# %% [markdown]
# 과제를 하면서 다시한번 리스트, 튜플, 사전에 대해서 공부하고 더 깊게 이해할 수 있었다. 머리로만 이해할때와 이렇게 직접 문제를 풀어볼때는 또 다른것 같다. 교수님께서 중요한 포인트를 과제로 내주셔서 공부하는데 도움이 많이 되었다.
